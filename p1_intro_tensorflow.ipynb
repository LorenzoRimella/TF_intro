# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LorenzoRimella/TF_intro/blob/main/p1_intro_tensorflow.ipynb)

# %% [markdown]
# # TensorFlow: funzionamento e utilizzi pratici

# %% [markdown]
# Iniziamo con l'importare le librerie principali. La libreria tensorflow è l'oggetto della presentazione, numpy verrà usata per un confronto, time per calcolare i running times, e matplotlib per i grafici.

# %%
import tensorflow as tf

import numpy as np

import time

import matplotlib.pyplot as plt
# Out:
# 2026-01-29 12:11:38.239147: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-29 12:11:38.267191: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-29 12:11:38.267223: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-29 12:11:38.267238: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-29 12:11:38.272821: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-29 12:11:39.725392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Vediamo se abbiamo una GPU disponibile

# %%
tf.config.list_physical_devices('GPU')
# Out:
# 2026-01-29 08:59:28.612220: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 08:59:31.090240: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 08:59:31.090288: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Tensori

# %% [markdown]
# Creare un tensore da una lista.
# Notiamo che dobbiamo sempre indicare il tipo di tensore (precisione del computer).

# %%
x_from_list_1 = tf.convert_to_tensor([100, 1, 1], dtype = tf.float32)
print("tensore 1 "+"\n", x_from_list_1)

x_from_list_2 = tf.convert_to_tensor([[100, 1], [1, 1]], dtype = tf.float32)
print("tensore 2 "+"\n", x_from_list_2)

x_from_list_3 = tf.convert_to_tensor([[[100, 1, 2], [100, 1, 2], [100, 100, 2]], [[2, 1, 2], [100, 1, 2], [2, 1, 2]]], dtype = tf.float32)
print("tensore 3 "+"\n", x_from_list_3)
# Out:
# 2026-01-29 12:11:41.715627: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.835625: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.835668: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.838648: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.838699: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.838717: I tensorflow/compile
# tensore 1
#  tf.Tensor([100.   1.   1.], shape=(3,), dtype=float32)
# tensore 2
#  tf.Tensor(
# [[100.   1.]
#  [  1.   1.]], shape=(2, 2), dtype=float32)
# tensore 3
#  tf.Tensor(
# [[[100.   1.   2.]
#   [100.   1.   2.]
#   [100. 100.   2.]]
#
#  [[  2.   1.   2.]
#   [100.   1.   2.]
#   [  2.   1.   2.]]], shape=(2, 3, 3), dtype=float32)
# r/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.940175: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.940236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.940242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-01-29 12:11:41.940266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-29 12:11:41.940284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# Possiamo anche crearlo direttamente da un numpy array. Questo può essere utile per comunicare con altre librerie, es. pandas, nella lettura dei dati.
# Notiamo che se non specifico il tipo viene assegnato uno di deafult, in questo caso int perché non ci sono virgole.

# %%
npx = np.array([100, 1, 1])

x_from_numpy = tf.convert_to_tensor(npx)
print("tensore da numpy "+"\n", x_from_numpy)
# Out:
# tensore da numpy
#  tf.Tensor([100   1   1], shape=(3,), dtype=int64)

# %% [markdown]
# Mentre in un numpy array possiamo cambiare gli elementi

# %%
npx = np.array([100, 1, 1])

npx[2] = -100

print("numpy array con nuovo elemento "+"\n", npx)
# Out:
# numpy array con nuovo elemento
#  [ 100    1 -100]

# %% [markdown]
# I tensori sono immutabili

# %%
npx = np.array([100, 1, 1])

x_from_numpy = tf.convert_to_tensor(npx)

x_from_numpy[2] = -100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 npx = np.array([100, 1, 1])
#       3 x_from_numpy = tf.convert_to_tensor(npx)
# ----> 5 x_from_numpy[2] = -100
#
# TypeError: 'tensorflow.python.framework.ops.EagerTensor' object does not support item assignment

# %% [markdown]
# ## Operazioni tra tensori

# %% [markdown]
# ### Operazioni elemento per elemento

# %% [markdown]
# Avere lo stesso tipo (compatibili) di tensori ci permette di eseguire operazioni su di essi, ma se non sono compatibili abbiamo un errore.

# %%
x_not_compatible_sum = x_from_numpy + x_from_list_1
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x_not_compatible_sum = x_from_numpy + x_from_list_1
#
# File ~/anaconda3/envs/tfwsl/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/anaconda3/envs/tfwsl/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:5888, in raise_from_not_ok_status(e, name)
#    5886 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5887   e.message += (" name: " + str(name if name is not None else ""))
# -> 5888   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: cannot compute AddV2 as input #1(zero-based) was expected to be a int64 tensor but is a float tensor [Op:AddV2] name:

# %% [markdown]
# Se abbiamo tensori compatibili possiamo sommarli

# %%
x_from_numpy_float32 = tf.convert_to_tensor(npx, dtype = tf.float32)
x_compatible_sum = x_from_numpy_float32 + x_from_list_1
print(x_compatible_sum)
# Out:
# tf.Tensor([200.   2.   2.], shape=(3,), dtype=float32)

# %% [markdown]
# farne la differenza

# %%
x_compatible_diff = x_from_numpy_float32 - x_from_list_1
print(x_compatible_diff)
# Out:
# tf.Tensor([0. 0. 0.], shape=(3,), dtype=float32)

# %% [markdown]
# moltiplicarli

# %%
x_compatible_prod = x_from_numpy_float32 * x_from_list_1
print(x_compatible_prod)
# Out:
# tf.Tensor([1.e+04 1.e+00 1.e+00], shape=(3,), dtype=float32)

# %% [markdown]
# dividerli

# %%
x_compatible_div = x_from_numpy_float32 / x_from_list_1
print(x_compatible_div)
# Out:
# tf.Tensor([1. 1. 1.], shape=(3,), dtype=float32)

# %% [markdown]
# e praticamente tutto quello che vogliamo: potenze, logaritmi, esponenziali, e altro... Google it!

# %%
x_compatible_pow = tf.math.pow(x_from_numpy_float32, 3)
print(x_compatible_pow)

x_compatible_log = tf.math.log(x_from_numpy_float32)
print(x_compatible_log)

x_compatible_exp = tf.math.exp(x_from_numpy_float32)
print(x_compatible_exp)
# Out:
# 2026-01-29 12:11:51.800140: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# tf.Tensor([1.00000006e+06 1.00000000e+00 1.00000000e+00], shape=(3,), dtype=float32)
# tf.Tensor([4.6051702 0.        0.       ], shape=(3,), dtype=float32)
# tf.Tensor([      inf 2.7182817 2.7182817], shape=(3,), dtype=float32)

# %% [markdown]
# ### Operazioni di riduzione

# %% [markdown]
# A volte vogliamo fare operazioni su dimensioni specifiche di tensori, per es. medie e somme, per farlo abbiamo le operazioni reduce

# %%
numpy_array_normal = np.random.normal(0, 1, (1000, 10))
x_normal = tf.convert_to_tensor(numpy_array_normal, dtype = tf.float32)

print("Somma le righe e mantieni la dimensione "+"\n", tf.reduce_sum(x_normal, axis = 0, keepdims = True))
print("Somma le righe "+"\n", tf.reduce_sum(x_normal, axis = 0))
# Out:
# Somma le righe e mantieni la dimensione
#  tf.Tensor(
# [[ 25.708994    0.6283407 -11.857092  -18.731598  -23.584732   27.577665
#   -44.37236   -21.692482   -0.3699875 -30.547346 ]], shape=(1, 10), dtype=float32)
# Somma le righe
#  tf.Tensor(
# [ 25.708994    0.6283407 -11.857092  -18.731598  -23.584732   27.577665
#  -44.37236   -21.692482   -0.3699875 -30.547346 ], shape=(10,), dtype=float32)

# %% [markdown]
# E per la media, massimo, minimo?

# %%
print(tf.reduce_mean(x_normal, axis = 0))
print(tf.reduce_max(x_normal, axis = 0))
print(tf.reduce_min(x_normal, axis = 0))
# Out:
# tf.Tensor(
# [ 0.02570899  0.00062834 -0.01185709 -0.0187316  -0.02358473  0.02757766
#  -0.04437236 -0.02169248 -0.00036999 -0.03054735], shape=(10,), dtype=float32)
# tf.Tensor(
# [3.623367  3.31829   3.171903  3.0964353 3.4453068 3.548233  3.2147336
#  2.9305573 3.0424497 2.9359434], shape=(10,), dtype=float32)
# tf.Tensor(
# [-2.8941364 -3.8775916 -3.4357924 -3.8641489 -3.4104438 -3.595208
#  -3.8174648 -2.813835  -3.0688915 -2.7226317], shape=(10,), dtype=float32)

# %% [markdown]
# ### Broadcasting

# %% [markdown]
# Come per numpy possiamo combinare tensori con le stesse dimensioni ma numero di elementi diversi tramite il broadcasting. Qui il tensore più piccolo viene proiettato su quello più grande.

# %%
numpy_array_normal_1 = np.random.normal(0, 1, (1000, 10))
x_normal_1 = tf.convert_to_tensor(numpy_array_normal_1, dtype = tf.float32)

numpy_array_normal_2 = np.random.normal(0, 1, (1000, 1))
x_normal_2 = tf.convert_to_tensor(numpy_array_normal_2, dtype = tf.float32)

print("Numero di elementi per dimenisone per il primo tensore "+"\n",   tf.shape(x_normal_1))
print("Numero di elementi per dimenisone per il secondo tensore "+"\n", tf.shape(x_normal_2))
print("Somma del primo tensore con il secondo tensore tramite broadcasting "+"\n", x_normal_1 + x_normal_2)
# Out:
# Numero di elementi per dimenisone per il primo tensore
#  tf.Tensor([1000   10], shape=(2,), dtype=int32)
# Numero di elementi per dimenisone per il secondo tensore
#  tf.Tensor([1000    1], shape=(2,), dtype=int32)
# Somma del primo tensore con il secondo tensore tramite broadcasting
#  tf.Tensor(
# [[-1.748021   -2.2208173  -1.2777827  ... -2.9029527  -0.2283622
#   -0.47928447]
#  [-0.7936339  -0.97388333 -0.578094   ...  0.21838045 -2.8955567
#    0.03262943]
#  [-0.9852204  -0.96449864 -0.90695155 ... -2.1173081  -1.982971
#   -0.89271474]
#  ...
#  [-1.2218845  -1.6700382  -1.1520233  ... -2.745733   -1.7312161
#   -1.3372219 ]
#  [ 0.5499425   1.1455338  -0.66843426 ...  1.3703699   0.81040853
#   -0.65617716]
#  [ 0.06597146  0.09257022  0.559784   ... -0.5061885   2.1952214
#   -1.8642815 ]], shape=(1000, 10), dtype=float32)

# %% [markdown]
# Il tensore piccolo deve poter essere replicato un numero esatto di volte senza ambiguità, altrimenti abbiamo un errore.

# %%
numpy_array_normal_3 = np.random.normal(0, 1, (1000, 2))
x_normal_3 = tf.convert_to_tensor(numpy_array_normal_3, dtype = tf.float32)

print("Numero di elementi per dimenisone per il primo tensore "+"\n", tf.shape(x_normal_3))
print("Numero di elementi per dimenisone per il secondo tensore "+"\n",tf.shape(x_normal_1) )
print("Somma del primo tensore con il secondo tensore tramite broadcasting "+"\n", x_normal_1 + x_normal_3)
# Out:
# Numero di elementi per dimenisone per il primo tensore
#  tf.Tensor([1000    2], shape=(2,), dtype=int32)
# Numero di elementi per dimenisone per il secondo tensore
#  tf.Tensor([1000   10], shape=(2,), dtype=int32)
# 2026-01-29 12:11:56.182526: W tensorflow/core/framework/op_kernel.cc:1827] INVALID_ARGUMENT: required broadcastable shapes
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[17], line 6
#       4 print("Numero di elementi per dimenisone per il primo tensore "+"\n", tf.shape(x_normal_3))
#       5 print("Numero di elementi per dimenisone per il secondo tensore "+"\n",tf.shape(x_normal_1) )
# ----> 6 print("Somma del primo tensore con il secondo tensore tramite broadcasting "+"\n", x_normal_1 + x_normal_3)
#
# File ~/anaconda3/envs/tfwsl/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/anaconda3/envs/tfwsl/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:5888, in raise_from_not_ok_status(e, name)
#    5886 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5887   e.message += (" name: " + str(name if name is not None else ""))
# -> 5888   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__AddV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} required broadcastable shapes [Op:AddV2] name:

# %% [markdown]
# Possiamo correggere le dimensioni usando expand_dims.

# %%
numpy_array_normal_4 = np.random.normal(0, 1, (1000, 100, 10, 50))
x_normal_4 = tf.convert_to_tensor(numpy_array_normal_4, dtype = tf.float32)

print("Numero di elementi per dimenisone per il primo tensore "+"\n", tf.shape(x_normal_1))
print("Numero di elementi per dimenisone per il secondo tensore "+"\n", tf.shape(x_normal_4))
# Out:
# Numero di elementi per dimenisone per il primo tensore
#  tf.Tensor([1000   10], shape=(2,), dtype=int32)
# Numero di elementi per dimenisone per il secondo tensore
#  tf.Tensor([1000  100   10   50], shape=(4,), dtype=int32)

# %% [markdown]
# Qui per esempio vogliamo espandere la seconda e l'ultima dimensione.

# %%
x_normal_expanded = tf.expand_dims(tf.expand_dims(x_normal_1, 1), -1)

print("Somma del primo tensore con il secondo tensore tramite broadcasting "+"\n", tf.reduce_sum(x_normal_expanded + x_normal_4))
# Out:
# Somma del primo tensore con il secondo tensore tramite broadcasting
#  tf.Tensor(-404752.94, shape=(), dtype=float32)

# %% [markdown]
# Nota che abbiamo portato come esempio la somma, ma il broadcasting funziona anche per differenza, prodotto, e divisione.

# %% [markdown]
# ### Operazioni tra dimensioni con einsum

# %% [markdown]
# La notazione di Einstein ci permette di effettuare operazioni di somma, prodotto, differenza, e divisione tra le dimensioni di tensori multidimensionali. Il caso più banale è il prodotto tra matrici e vettori.

# %%
numpy_array_A = np.random.normal(0, 1, (10, 10))
A = tf.convert_to_tensor(numpy_array_A, dtype = tf.float32)

numpy_array_b = np.random.normal(0, 1, (10))
b = tf.convert_to_tensor(numpy_array_b, dtype = tf.float32)

print("Prodotto tra la matrice e il vettore "+"\n", tf.einsum("ij,j->i", A, b))
# Out:
# Prodotto tra la matrice e il vettore
#  tf.Tensor(
# [-1.581196  -2.918889  -4.4248457  3.4837     3.4155326 -1.3107638
#   3.903708   3.0415788  3.4751291  0.9945919], shape=(10,), dtype=float32)

# %% [markdown]
# Il grosso vantaggio è che possiamo farlo anche su tensori di matrici.

# %%
numpy_array_A = np.random.normal(0, 1, (1000, 100, 10, 10))
A = tf.convert_to_tensor(numpy_array_A, dtype = tf.float32)

numpy_array_b = np.random.normal(0, 1, (1000, 100, 10))
b = tf.convert_to_tensor(numpy_array_b, dtype = tf.float32)

print("Prodotto tra tensori di matrici e di vettori "+"\n", tf.einsum("nhij,nhj->nhi", A, b))
print("Prodotto tra tensori di matrici e di vettori "+"\n", tf.einsum("...ij,...j->...i", A, b))
# Out:
# Prodotto tra tensori di matrici e di vettori
#  tf.Tensor(
# [[[ 1.9582394e+00  6.1584749e+00  5.0009651e+00 ...  1.4566680e+00
#    -1.3881352e+00 -3.4239745e+00]
#   [ 1.5352664e+00 -2.9940403e-01 -2.3092670e+00 ... -5.0839224e+00
#    -2.0912259e+00 -4.1193900e+00]
#   [-6.1926050e+00 -4.9358349e+00  9.3309277e-01 ...  7.3121905e-01
#    -1.0950205e+00  1.8996549e+00]
#   ...
#   [ 4.9547344e-01  1.9935179e+00  2.1836383e+00 ...  4.1551185e-01
#     2.4184055e+00  1.4609373e+00]
#   [-2.6348364e+00  4.4511714e+00  3.2794054e+00 ...  2.9845774e+00
#     3.6504161e-01  8.4355378e-01]
#   [-3.5415134e+00  1.2548697e+00  4.4123173e-01 ...  5.5852091e-01
#    -9.7164762e-01 -5.7463570e+00]]
#
#  [[-1.1038048e+00 -3.2785730e+00  7.2885984e-01 ... -2.5403042e+00
#     1.1653258e+00 -6.6107154e-01]
#   [ 3.0134001e+00  5.7279067e+00 -2.4322586e+00 ...  6.6931033e-01
#    -3.8811567e+00 -1.3865888e+00]
#   [ 1.3968614e+00  8.7169558e-01 -5.4624357e+00 ...  7.0622826e-01
#    -1.1291647e+00  6.1736751e-01]
#   ...
#   [-8.7931156e-01  2.4768333e+00 -2.1031070e+00 ...  2.2229843e+00
#    -1.1145504e+00  1.2065934e+00]
#   [-5.4850779e+00  3.0946040e-01 -2.4538472e-02 ... -7.5773382e+00
#    -2.4400902e-01 -5.0674934e+00]
#   [ 1.7000511e+00 -1.2731063e+00  3.8908978e+00 ... -3.6287618e+00
#     1.7654389e+00  3.6484601e+00]]
#
#  [[-1.7632017e-01  6.9099677e-01 -2.4973726e+00 ... -1.7618160e+00
#    -1.0367204e+00 -3.2758038e+00]
#   [-6.2879438e+00 -2.8320656e+00 -3.7659123e+00 ...  5.4453478e+00
#     4.2467608e+00 -3.2232490e+00]
#   [ 5.0791655e+00  3.8005919e+00 -5.3997478e+00 ... -2.1718979e+00
#     2.0688465e+00  4.9065433e+00]
#   ...
#   [-1.2280629e+00  2.2992678e+00 -1.9599547e+00 ... -1.4349004e+00
#    -2.8686421e+00  7.7095735e-01]
#   [ 1.4955537e+00  2.5921124e-01 -3.5629356e+00 ...  9.6996546e-02
#    -1.4633292e+00  3.1712294e+00]
#   [ 3.9858437e+00 -1.4713730e+00  9.9322611e-01 ...  4.4166451e+00
#     2.2886255e+00 -5.5034389e+00]]
#
#  ...
#
#   [ 6.3408613e-01  7.8906422e+00 -2.4727366e+00 ...  2.7949820e+00
#     3.8297398e+00 -6.8830862e+00]
#   [ 4.5045018e-02  2.2540722e+00  1.6158655e+00 ...  2.1936667e+00
#     3.8889728e+00  1.0583334e+00]
#   [ 1.4630702e+00  2.3134089e+00  1.3363912e+00 ...  3.6852428e-01
#    -1.4044261e+00  2.5854025e+00]]
#
#  [[ 1.1457562e+00  1.4241921e+00  2.0618601e+00 ... -3.5418963e-01
#     2.1144390e+00  9.4377100e-02]
#   [ 5.3077469e+00  4.7483335e+00  1.7236887e-02 ...  2.7320976e+00
#    -2.7639692e+00 -1.6447706e+00]
#   [ 2.6807290e-01 -1.9625287e+00 -1.7241503e+00 ... -6.6027522e-02
#     4.4252276e-02 -2.1682098e+00]
#   ...
#   [ 2.4489567e-01 -9.2887602e+00 -5.5681496e+00 ... -2.4302878e+00
#     3.1627438e+00  1.0068536e+00]
#   [-7.2710717e-01 -5.3518257e+00  2.5543115e+00 ...  3.8531992e-01
#    -5.6186914e-02 -5.0734777e+00]
#   [ 4.2076712e+00 -2.0671630e+00 -1.4423032e+00 ...  5.7090497e+00
#     5.3343290e-01 -3.6872163e+00]]], shape=(1000, 100, 10), dtype=float32)

# %% [markdown]
# L'importante è che le dimensioni su cui effettuiamo l'operazione rispettino le dimensioni.

# %%
numpy_array_A = np.random.normal(0, 1, (1000, 100, 10, 10))
A = tf.convert_to_tensor(numpy_array_A, dtype = tf.float32)

numpy_array_b = np.random.normal(0, 1, (100, 10))
b = tf.convert_to_tensor(numpy_array_b, dtype = tf.float32)

print("Prodotto tra tensori di matrici e di vettori "+"\n", tf.einsum("...hij,hj->...hi", A, b))
# Out:
# Prodotto tra tensori di matrici e di vettori
#  tf.Tensor(
# [[[ 4.56266940e-01 -1.01984119e+01 -5.08297348e+00 ...  3.75865841e+00
#     1.05259383e+00  1.53140306e+00]
#   [ 6.47666264e+00 -2.92385197e+00  1.40310502e+00 ... -1.58772945e+00
#     4.10898113e+00  8.35060298e-01]
#   [-3.43680263e+00 -1.53481483e+00 -1.84190416e+00 ... -1.59863621e-01
#     8.34466398e-01  1.84888315e+00]
#   ...
#   [-6.06651497e+00  5.65491772e+00 -1.72333765e+00 ...  3.02676702e+00
#    -3.17447138e+00  2.67379194e-01]
#   [-1.01768947e+00 -2.73479223e+00  5.74726534e+00 ... -5.26967585e-01
#     3.92943025e-02 -1.20569980e+00]
#   [ 6.87764645e-01 -2.82484555e+00  3.88754535e+00 ... -8.01692009e-01
#     5.54997826e+00 -1.12410426e-01]]
#
#  [[ 3.96970868e+00  1.22033989e+00 -9.46956062e+00 ... -1.14436321e+01
#     3.00445986e+00 -8.61346722e-03]
#   [ 3.10830164e+00  4.43831110e+00 -8.69846463e-01 ... -2.83550596e+00
#    -4.82094574e+00  3.26932764e+00]
#   [ 2.12186193e+00  5.85677624e-01  1.02281606e+00 ...  1.85232687e+00
#     1.00202346e+00  1.51713812e+00]
#   ...
#   [ 3.28324747e+00 -2.58622408e-01  4.36891556e+00 ...  4.85844612e-02
#    -3.80142856e+00  3.60571814e+00]
#     3.49764138e-01  3.93086815e+00]
#   ...
#   [ 5.59267664e+00  2.60171318e+00  3.08781576e+00 ... -1.99805462e+00
#    -4.32768059e+00 -1.05461884e+00]
#   [ 3.05823779e+00 -3.01119757e+00 -2.89660692e-01 ...  2.71376753e+00
#    -5.10892439e+00  1.02460921e+00]
#   [-5.97945976e+00 -4.16795206e+00  4.41965151e+00 ... -6.45660019e+00
#    -4.25357282e-01 -3.75632811e+00]]], shape=(1000, 100, 10), dtype=float32)

# %% [markdown]
# ## Confronti di performance

# %%
numpy_array_A = np.random.normal(0, 1, (10000, 100, 10, 10))
A = tf.convert_to_tensor(numpy_array_A, dtype = tf.float32)

numpy_array_b = np.random.normal(0, 1, (10000, 100, 10))
b = tf.convert_to_tensor(numpy_array_b, dtype = tf.float32)

# %%
start = time.time()
for n in range(10000):
	for h in range(100):

		np.matmul(numpy_array_A[n,h,...], numpy_array_b[n,h,...])
		
print("Gira in ", time.time()-start)
# Out:
# Gira in  0.7964339256286621

# %%
start = time.time()
np.einsum("nhij,nhj->nhi", numpy_array_A, numpy_array_b)		
print("Gira in ", time.time()-start)
# Out:
# Gira in  0.06905555725097656

# %%
start = time.time()
tf.einsum("nhij,nhj->nhi", A, b)		
print("Gira in ", time.time()-start)
# Out:
# Gira in  0.0010752677917480469

# %% [markdown]
# ## Quando usare numpy?

# %% [markdown]
# La libreria numpy ha un sacco di supporto per altre librerie, risulta quindi più facile maneggiare dati e fare plot quando si usa numpy. Possiamo sempre convertire un tensor in un numpy array usando .numpy()

# %%
print("La matrice A convertita in numpy array diventa "+"\n", A.numpy())
# Out:
# La matrice A convertita in numpy array diventa
#  [[[[ 1.42241883e+00  1.12223303e+00 -1.06671542e-01 ... -3.16043347e-01
#     -3.21683645e-01  9.43805397e-01]
#    [-1.04785800e-01 -5.90667129e-02  3.98306191e-01 ...  2.71232605e-01
#      1.45102167e+00  1.34236574e+00]
#    [-9.91421472e-03 -4.49905962e-01  9.44886923e-01 ...  7.33160377e-01
#      9.85564291e-01 -3.36125284e-01]
#    ...
#    [-5.16976297e-01  1.60936236e+00  5.03846109e-01 ...  4.91272420e-01
#      5.31996191e-01 -3.18534207e+00]
#    [-1.50251746e+00 -9.47071135e-01  3.29264075e-01 ...  6.86044574e-01
#      4.18723911e-01 -3.40483069e-01]
#    [-2.42253706e-01 -1.42784202e+00  1.21798790e+00 ... -3.41802776e-01
#     -3.95790279e-01 -1.45068884e+00]]
#
#   [[ 5.85607111e-01  8.71514380e-01 -1.15496540e+00 ...  6.89052284e-01
#      4.06887382e-01  1.92017704e-01]
#    [-4.40807045e-01  5.45558870e-01 -3.43529493e-01 ... -7.35148847e-01
#      6.95457816e-01  7.20067978e-01]
#    [-3.32945704e-01  4.36618268e-01 -1.91479731e+00 ... -3.61218750e-01
#      7.29876220e-01 -4.04355824e-01]
#    ...
#    [-5.79462349e-01  7.88501799e-01 -4.36097294e-01 ... -3.66379581e-02
#      2.18283564e-01 -8.55327129e-01]
#    [ 7.73213923e-01  8.84704649e-01 -2.04234257e-01 ... -3.32872272e-02
